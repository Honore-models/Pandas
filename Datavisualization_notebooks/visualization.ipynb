# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

products = pd.read_csv("products.csv", index_col="Product ID")
plt.title("Lineplot for products")
sns.lineplot(data=products)
# sns.lineplot(data=products['Price'], label="Price")
products
# Out:
#                                         Name            Category  Price  Stock
# Product ID
# 1            Wireless Bluetooth Headphones     Electronics        79.99    150
# 2            Stainless Steel Water Bottle      Kitchen & Home     24.99    320
# 3            Yoga Mat Pro                      Sports & Fitness   45.00    200
# 4            LED Desk Lamp                     Office Supplies    34.50    180
# 5            Organic Green Tea (100 bags)      Food & Beverages   18.99    500
# 6            Running Shoes - Men's             Footwear           95.00     75
# 7            Laptop Stand Adjustable           Office Supplies    52.00    140
# 8            Cotton Bath Towel Set             Home & Bath        39.99    260
# 9            Portable Phone Charger 20000mAh   Electronics        49.99    110
# 10           Non-stick Frying Pan 28cm         Kitchen & Home     29.99    190
# 11           Resistance Bands Set              Sports & Fitness   22.50    350
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

products = pd.read_csv("products.csv", index_col="ID")
plt.title("Products barchat")
sns.barplot(x=products.Stock, y=products.Price)
# Out:
# <Axes: title={'center': 'Products barchat'}, xlabel='Stock', ylabel='Price'>
