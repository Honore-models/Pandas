# %%
import pandas as pd
fruits = pd.DataFrame({"Apples": [30], "Bananas": [21]})
fruits
# Out:
#    Apples  Bananas
# 0      30       21

# %%
fruit_sales = pd.DataFrame({"Apples" : [35,41], "Bananas": [21,34]},index = ["2017 Sales", "2018 Sales"])
fruit_sales
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %%
import pandas as pd
ingredients = pd.Series(["4 cups","1 cup","2 large","1 can"], index = ["Flour", "Milk", "Eggs", "Spam"], name = "Dinner")
ingredients

#ingredients.loc["Flour"]
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %%
import pandas as pd
animals = pd.DataFrame({'Cows': [12, 20], 'Goats': [22, 19]}, index=['Year 1', 'Year 2'])
animals

animals.to_csv('cows_and_goats.csv')

# %%
import pandas as pd
products = pd.read_csv("products.csv")
products.loc[[1,2,3,4]]
products.iloc[:4]
# Out:
#   Product ID                   Product Name          Category  Price (USD)  \
# 0       P001  Wireless Bluetooth Headphones       Electronics        79.99
# 1       P002   Stainless Steel Water Bottle    Kitchen & Home        24.99
# 2       P003                   Yoga Mat Pro  Sports & Fitness        45.00
# 3       P004                  LED Desk Lamp   Office Supplies        34.50
#
#    Stock Quantity
# 0             150
# 1             320
# 2             200
# 3             180

# %%
import pandas as pd
products = pd.read_csv("products.csv")
products
# Out:
#    Product ID                     Product Name           Category  \
# 0        P001    Wireless Bluetooth Headphones        Electronics
# 1        P002     Stainless Steel Water Bottle     Kitchen & Home
# 2        P003                     Yoga Mat Pro   Sports & Fitness
# 3        P004                    LED Desk Lamp    Office Supplies
# 4        P005     Organic Green Tea (100 bags)   Food & Beverages
# 5        P006            Running Shoes - Men's           Footwear
# 6        P007          Laptop Stand Adjustable    Office Supplies
# 7        P008            Cotton Bath Towel Set        Home & Bath
# 8        P009  Portable Phone Charger 20000mAh        Electronics
# 9        P010        Non-stick Frying Pan 28cm     Kitchen & Home
# 10       P011             Resistance Bands Set   Sports & Fitness
# 11       P012               Scented Soy Candle         Home Decor
# 12       P013          Wireless Computer Mouse        Electronics
# 13       P014             Bamboo Cutting Board     Kitchen & Home
# 14       P015     Vitamin C Supplement 60 Tabs  Health & Wellness
#
#     Price (USD)  Stock Quantity
# 0         79.99             150
# 1         24.99             320
# 2         45.00             200
# 3         34.50             180
# 4         18.99             500
# 5         95.00              75
# 6         52.00             140
# 7         39.99             260
# 8         49.99             110
# 9         29.99             190
# 10        22.50             350
# 11        16.00             400
# 12        27.99             230
# 13        21.00             175
# 14        14.99             600
